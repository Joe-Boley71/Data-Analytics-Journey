# %%
# Python Functions Exercise

"""
In this exercise, you'll practice creating and using functions in Python.
Follow the instructions for each task and implement the required functions.
"""

# %%
# Task 1: Basic Function
# Create a function named 'hello_world' that prints "Hello, world!"
# Your code here

def hello_world():
    print("Hello, world!")

# Test Task 1
print("Task 1 Test:")
# Call your hello_world function
hello_world()
# Out:
# Task 1 Test:
# Hello, world!

# %%
# Task 2: Function with a Parameter
# Create a function named 'greet' that takes a name parameter 
# and prints a personalized greeting
# Your code here

def greet(name_given):
    print(f'Greetings, {name_given}')

# Test Task 2
print("Task 2 Test:")

# Call your greet function with different names
greet("joseph")
# Out:
# Task 2 Test:
# Greetings, joseph

# %%
# Task 3: Function with Multiple Parameters
# Create a function named 'calculate_area' that calculates the area of a rectangle
# It should take two parameters: length and width
# Your code here

def calculate_area(length, width):
    area = length * width
    return area

# Test Task 3
print("Task 3 Test:")
# Call your calculate_area function with different dimensions
# Print the results
result = calculate_area(10,5)
print(f'Area: {result}')
# Out:
# Task 3 Test:
# Area: 50

# %%
# Task 4: Function with Default Parameter Values
# Create a function named 'power' that calculates a number raised to a power
# The function should take two parameters: base and exponent (default to 2)
# Your code here

def power(base, exponent=2):
    result = base ** exponent
    return result

# Test Task 4
print("Task 4 Test:")
# Call your power function with and without specifying the exponent
# Print the results
print(power(2))
print(power(2, 6))
# Out:
# Task 4 Test:
# 4
# 64

# %%
# Task 5: Function that Returns a Value
# Create a function named 'get_full_name' that combines first, middle, and last names
# The middle name should be optional
# Your code here

def get_full_name(first_name, last_name, middle_name=""):
    if middle_name:
        return f"{first_name} {middle_name} {last_name}"
    return f"{first_name} {last_name}"
    
# Test Task 5
print("Task 5 Test:")
# Call your get_full_name function with and without a middle name
# Print the results
full_name = get_full_name("Joseph", "Boley")
full_name2 = get_full_name("Joseph", "Boley", "Aaron")

print(full_name)
print(full_name2)
# Out:
# Task 5 Test:
# Joseph Boley
# Joseph Aaron Boley

# %%
# Task 6: Function Composition
# Create two functions:
# 1. 'celsius_to_fahrenheit' that converts a temperature from Celsius to Fahrenheit
# 2. 'fahrenheit_to_celsius' that converts a temperature from Fahrenheit to Celsius
# Formula: F = C * 9/5 + 32
# Your code here

def celsius_to_fahrenheit(celsius_temp):
    converted_fahrenheit = celsius_temp * 9/5 + 32
    return converted_fahrenheit
    pass

def fahrenheit_to_celsius(fahrenheit_temp):
    converted_celsius = (fahrenheit_temp - 32) * 5/9
    return converted_celsius
    pass

# Test Task 6
print("Task 6 Test:")
# Convert some temperatures both ways
# Print the results
print(f'0 Celsius is {celsius_to_fahrenheit(0)} Fahrenheit')
print(f'100 Celsius is {celsius_to_fahrenheit(100)} Fahrenheit')

print(f'32 Fahrenheit is {fahrenheit_to_celsius(32)} Celsius')
print(f'212 Fahrenheit is {fahrenheit_to_celsius(212)} Celsius')
print()
# Out:
# Task 6 Test:
# 0 Celsius is 32.0 Fahrenheit
# 100 Celsius is 212.0 Fahrenheit
# 32 Fahrenheit is 0.0 Celsius
# 212 Fahrenheit is 100.0 Celsius

# %%
# Task 7: Combining Functions and Conditionals
# Create a function named 'analyze_temperature' that:
# 1. Takes a temperature value and a unit ('C' or 'F')
# 2. Converts the temperature to the other unit
# 3. Returns a string describing if it's "freezing" (below 0°C), 
#    "cold" (0-15°C), "moderate" (15-25°C), or "hot" (above 25°C)
# Your code here

def analyze_temperature(temperature_value, temperature_unit):
    if temperature_unit.upper() == "F":
        temperature_value = (temperature_value - 32) * 5/9
    elif temperature_unit.upper() == "C":
        converted_value = temperature_value * 9/5 + 32
        pass
    else:
        return f"Error, Please Select Correct Values"

    if temperature_value < 0:
        return f"The temperature {temperature_value} is Freezing"
    elif 0 <= temperature_value < 15:
        return f"The temperature {temperature_value} is Cold"
    elif 15 <= temperature_value < 25:
        return f"The temperature {temperature_value} is Moderate"
    else:
        return f"The Temperature {temperature_value} is Hot"

# Test Task 7
print("Task 7 Test:")
# Test with different temperatures in both Celsius and Fahrenheit
# Print the results
print(analyze_temperature(0, "f"))
print(analyze_temperature(0, "c"))
print()
# Out:
# Task 7 Test:
# The temperature -17.77777777777778 is Freezing
# The temperature 0 is Cold

# %%
# Task 8: Function with Variable Arguments
# Create a function named 'calculate_average' that:
# 1. Accepts any number of numeric arguments
# 2. Returns the average of all numbers provided
# Your code here

# *args = multiple arguments in a tuple
# **kwargs = multiple arguments in a dictionary

def calculate_average(*numbers):
    if not numbers:
        return 0
    total = sum(numbers)
    count = len(numbers)
    return total / count

# Test Task 8
print("Task 8 Test:")
# Call your calculate_average function with different sets of numbers
# Print the results
print(f"Average of (10, 20, 30): {calculate_average(10,20,30)}")
print(f"Average of (5, 15): {calculate_average(5,15)}")
print(f"Average of no numbers: {calculate_average()}")
print()
# Out:
# Task 8 Test:
# Average of (10, 20, 30): 20.0
# Average of (5, 15): 10.0
# Average of no numbers: 0

# %%
# Task 9: Advanced Challenge - Student Grade Function
# Create a function named 'calculate_final_grade' that:
# 1. Takes a student's name and any number of assignment scores
# 2. Calculates the average score
# 3. Determines the letter grade based on the average (A: 90+, B: 80-89, C: 70-79, D: 60-69, F: <60)
# 4. Returns a formatted string with the student's name, average score, and letter grade
# Your code here

def calculate_final_grade(name, *scores):
    if not scores:
        return f"{name} has encountered error 404: no scores found"
    total = sum(scores)
    count = len(scores)
    average = total / count

    if average >= 90:
        grade_letter = "A"
        
    elif 80 <= average < 90:
        grade_letter = "B"
        
    elif 70 <= average < 80:
        grade_letter = "C"
        
    elif 60 <= average < 70:
        grade_letter = "D"
        
    elif average < 60:
        grade_letter = "F"

    return f'(Name: {name} || Average Grade: {average} || Letter Grade: {grade_letter})'

# Test Task 9
print("Task 9 Test:")
# Test with different student names and scores
# Print the results
print(calculate_final_grade("Joseph", 10, 20, 30))
print(calculate_final_grade("Jane", 50, 90, 85))
print()
# Out:
# Task 9 Test:
# (Name: Joseph || Average Grade: 20.0 || Letter Grade: F)
# (Name: Jane || Average Grade: 75.0 || Letter Grade: C)
