# %%
# Exercise 1: Lists and Dictionaries

"""
Instructions:
1. Create a shopping list with at least 5 items
2. Print out the third item in the list
3. Replace the first item with a different item
4. Add an item to the end of the list
5. Create a dictionary of 3 grocery items with their prices
6. Print a message showing one item and its price
7. Add a new item to the dictionary with its price
8. Calculate and print the total cost of all items
"""

# %%
# Your solution here:
# Tasks 1-4

#Task 1
### created a list with 6 items
shopping_list = ["Apples", "Brownies", "Potatoes", "Milk", "Milkies", "Roast Beef"]

#Task 2
### used the index 2 as Python indexes at 0 to start
print(shopping_list[2])

#Task 3
### using the index 0 for Python indexes at 0, replaces Apples with Not-Apples
shopping_list[0] = "Not Apples"
#print(shopping_list)

#Task 4
### using .append(), adds pop to the list
shopping_list.append("Soda Pop")
#print(shopping_list)
# Out:
# Potatoes

# %%
#Tasks 5-8

# task 5
### creates a list of 3 items
shopping_dictionary = {"Apples": 5.05, "Brownies": 10.00, "Milkies": 0.89}

# task 6
### uses a for loop to print out the key-value pair of the first item, breaks the loop afterwards
### TO-DO: figure out a less hack-y way to complete this task
for i,j in shopping_dictionary.items():
    print(i,j)
    break

# task 7
#using update, adds potatoes to the dictionary
shopping_dictionary.update({"Potatoes": 8.99})

# task 8
### using sum() and dictionary method .values() to add up the value of the values in the key-value pair
### prints it in a formatted string otherwise
total_price = sum(shopping_dictionary.values())
print(f'Total Price of all of the items: {total_price}')
# Out:
# Apples 5.05
# Total Price of all of the items: 24.93
