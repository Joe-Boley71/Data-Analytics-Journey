# %%
import pandas as pd

# %%
df = pd.read_csv('students.csv')

# %%
# # 2. Changing delimiter (sep)

df = pd.read_csv('students.csv', sep=',')

# %%
# setting column as index
df = pd.read_csv('students.csv', index_col='Name')

# %%
df = pd.read_csv('students.csv', usecols=['Name', 'Grade'])

# %%
df = pd.read_csv('students.csv', names=['Student', 'Years', 'Score', "Location"], header=0)

# %%
df = pd.read_csv('students.csv', dtype={'Age': 'float', 'Grade': 'int'})

# %%
cols_names = df.columns

# %%
df = pd.read_csv('students.csv', skiprows-3, names=cols_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df = pd.read_csv('students.csv', skiprows-3, names=cols_names)
#
# NameError: name 'skiprows' is not defined

# %%
df = pd.read_csv('students_updated.csv', na_values = ['N/A', 'unknown'])

# %%
df = pd.read_csv('students_updated.csv', parse_dates=['EnrollmentDate'])

# %%
df.isnull().sum()
# Out:
# Name               0
# Age                1
# Grade              1
# City               1
# EnrollmentDate    10
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
# basic import .xlsx
pip install openpyxl
# Out:
#   Cell In[68], line 2
#     pip install openpyxl
#         ^
# SyntaxError: invalid syntax
